# %%
import requests

# %%
variable_code="12"
country_id="710"
start_year=2022
end_year=2022

target = ("https://population.un.org/dataportalapi/api/v1/data/indicators/"+ variable_code
        + "/locations/"
        + country_id
        + "/start/"
        + str(start_year)
        + "/end/"
        + str(end_year))

response = requests.get(target)

# %%
j = response.json()

# %%
j
# Out:
# {'pageNumber': 1,
#  'pageSize': 100,
#  'previousPage': None,
#  'nextPage': None,
#  'pages': 1,
#  'total': 15,
#  'data': [{'locationId': 710,
#    'location': 'South Africa',
#    'iso3': 'ZAF',
#    'iso2': 'ZA',
#    'locationTypeId': 4,
#    'indicatorId': 12,
#    'indicator': 'Unmet need for family planning: Any modern method (Number)',
#    'indicatorDisplayName': 'Unmet need modern',
#    'sourceId': 23,
#    'source': 'Estimates and Projections of Family Planning Indicators',
#    'revision': 0,
#    'variantId': 1,
#    'variant': '95% lower bound',
#    'variantShortName': 'LOWER95',
#    'variantLabel': '95% Lower',
#    'timeId': 73,
#    'timeLabel': '2022',
#    'timeMid': '2022.5',
#    'categoryId': 99,
#    'category': 'All women',
#    'estimateTypeId': 1,
#    'estimateType': 'Model-based Estimates',
#    'estimateMethodId': 3,
#    'estimateMethod': 'Projection',
#    'sexId': 2,
#    'sex': 'Female',
#    'ageId': 31,
#    'ageLabel': '15-49',
#    'ageStart': 15,
#    'ageEnd': 49,
#    'ageMid': 32.5,
#    'value': 1284360},
#   {'locationId': 710,
#    'location': 'South Africa',
#    'iso3': 'ZAF',
#    'iso2': 'ZA',
#    'locationTypeId': 4,
#    'indicatorId': 12,
#    'indicator': 'Unmet need for family planning: Any modern method (Number)',
#    'indicatorDisplayName': 'Unmet need modern',
#    'sourceId': 23,
#    'source': 'Estimates and Projections of Family Planning Indicators',
#    'revision': 0,
#    'variantId': 1,
#    'variant': '95% lower bound',
#    'variantShortName': 'LOWER95',
#    'variantLabel': '95% Lower',
#    'timeId': 73,
#    'timeLabel': '2022',
#    'timeMid': '2022.5',
#    'categoryId': 100,
#    'category': 'Married or in a union women',
#    'estimateTypeId': 1,
#    'estimateType': 'Model-based Estimates',
#    'estimateMethodId': 3,
#    'estimateMethod': 'Projection',
#    'sexId': 2,
#    'sex': 'Female',
#    'ageId': 31,
#    'ageLabel': '15-49',
#    'ageStart': 15,
#    'ageEnd': 49,
#    'ageMid': 32.5,
#    'value': 611368},
#   {'locationId': 710,
#    'location': 'South Africa',
#    'iso3': 'ZAF',
#    'iso2': 'ZA',
#    'locationTypeId': 4,
#    'indicatorId': 12,
#    'indicator': 'Unmet need for family planning: Any modern method (Number)',
#    'indicatorDisplayName': 'Unmet need modern',
#    'sourceId': 23,
#    'source': 'Estimates and Projections of Family Planning Indicators',
#    'revision': 0,
#    'variantId': 1,
#    'variant': '95% lower bound',
#    'variantShortName': 'LOWER95',
#    'variantLabel': '95% Lower',
#    'timeId': 73,
#    'timeLabel': '2022',
#    'timeMid': '2022.5',
#    'categoryId': 101,
#    'category': 'Unmarried women',
#    'estimateTypeId': 1,
#    'estimateType': 'Model-based Estimates',
#    'estimateMethodId': 3,
#    'estimateMethod': 'Projection',
#    'sexId': 2,
#    'sex': 'Female',
#    'ageId': 31,
#    'ageLabel': '15-49',
#    'ageStart': 15,
#    'ageEnd': 49,
#    'ageMid': 32.5,
#    'value': 614722},
#   {'locationId': 710,
#    'location': 'South Africa',
#    'iso3': 'ZAF',
#    'iso2': 'ZA',
#    'locationTypeId': 4,
#    'indicatorId': 12,
#    'indicator': 'Unmet need for family planning: Any modern method (Number)',
#    'indicatorDisplayName': 'Unmet need modern',
#    'sourceId': 23,
#    'source': 'Estimates and Projections of Family Planning Indicators',
#    'revision': 0,
#    'variantId': 2,
#    'variant': '80% lower bound',
#    'variantShortName': 'LOWER80',
#    'variantLabel': '80% Lower',
#    'timeId': 73,
#    'timeLabel': '2022',
#    'timeMid': '2022.5',
#    'categoryId': 99,
#    'category': 'All women',
#    'estimateTypeId': 1,
#    'estimateType': 'Model-based Estimates',
#    'estimateMethodId': 3,
#    'estimateMethod': 'Projection',
#    'sexId': 2,
#    'sex': 'Female',
#    'ageId': 31,
#    'ageLabel': '15-49',
#    'ageStart': 15,
#    'ageEnd': 49,
#    'ageMid': 32.5,
#    'value': 1054531},
#   {'locationId': 710,
#    'location': 'South Africa',
#    'iso3': 'ZAF',
#    'iso2': 'ZA',
#    'locationTypeId': 4,
#    'indicatorId': 12,
#    'indicator': 'Unmet need for family planning: Any modern method (Number)',
#    'indicatorDisplayName': 'Unmet need modern',
#    'sourceId': 23,
#    'source': 'Estimates and Projections of Family Planning Indicators',
#    'revision': 0,
#    'variantId': 2,
#    'variant': '80% lower bound',
#    'variantShortName': 'LOWER80',
#    'variantLabel': '80% Lower',
#    'timeId': 73,
#    'timeLabel': '2022',
#    'timeMid': '2022.5',
#    'categoryId': 100,
#    'category': 'Married or in a union women',
#    'estimateTypeId': 1,
#    'estimateType': 'Model-based Estimates',
#    'estimateMethodId': 3,
#    'estimateMethod': 'Projection',
#    'sexId': 2,
#    'sex': 'Female',
#    'ageId': 31,
#    'ageLabel': '15-49',
#    'ageStart': 15,
#    'ageEnd': 49,
#    'ageMid': 32.5,
#    'value': 510295},
#   {'locationId': 710,
#    'location': 'South Africa',
#    'iso3': 'ZAF',
#    'iso2': 'ZA',
#    'locationTypeId': 4,
#    'indicatorId': 12,
#    'indicator': 'Unmet need for family planning: Any modern method (Number)',
#    'indicatorDisplayName': 'Unmet need modern',
#    'sourceId': 23,
#    'source': 'Estimates and Projections of Family Planning Indicators',
#    'revision': 0,
#    'variantId': 2,
#    'variant': '80% lower bound',
#    'variantShortName': 'LOWER80',
#    'variantLabel': '80% Lower',
#    'timeId': 73,
#    'timeLabel': '2022',
#    'timeMid': '2022.5',
#    'categoryId': 101,
#    'category': 'Unmarried women',
#    'estimateTypeId': 1,
#    'estimateType': 'Model-based Estimates',
#    'estimateMethodId': 3,
#    'estimateMethod': 'Projection',
#    'sexId': 2,
#    'sex': 'Female',
#    'ageId': 31,
#    'ageLabel': '15-49',
#    'ageStart': 15,
#    'ageEnd': 49,
#    'ageMid': 32.5,
#    'value': 466864},
#   {'locationId': 710,
#    'location': 'South Africa',
#    'iso3': 'ZAF',
#    'iso2': 'ZA',
#    'locationTypeId': 4,
#    'indicatorId': 12,
#    'indicator': 'Unmet need for family planning: Any modern method (Number)',
#    'indicatorDisplayName': 'Unmet need modern',
#    'sourceId': 23,
#    'source': 'Estimates and Projections of Family Planning Indicators',
#    'revision': 0,
#    'variantId': 4,
#    'variant': 'Median',
#    'variantShortName': 'Median',
#    'variantLabel': 'Median',
#    'timeId': 73,
#    'timeLabel': '2022',
#    'timeMid': '2022.5',
#    'categoryId': 99,
#    'category': 'All women',
#    'estimateTypeId': 1,
#    'estimateType': 'Model-based Estimates',
#    'estimateMethodId': 3,
#    'estimateMethod': 'Projection',
#    'sexId': 2,
#    'sex': 'Female',
#    'ageId': 31,
#    'ageLabel': '15-49',
#    'ageStart': 15,
#    'ageEnd': 49,
#    'ageMid': 32.5,
#    'value': 1775802},
#   {'locationId': 710,
#    'location': 'South Africa',
#    'iso3': 'ZAF',
#    'iso2': 'ZA',
#    'locationTypeId': 4,
#    'indicatorId': 12,
#    'indicator': 'Unmet need for family planning: Any modern method (Number)',
#    'indicatorDisplayName': 'Unmet need modern',
#    'sourceId': 23,
#    'source': 'Estimates and Projections of Family Planning Indicators',
#    'revision': 0,
#    'variantId': 4,
#    'variant': 'Median',
#    'variantShortName': 'Median',
#    'variantLabel': 'Median',
#    'timeId': 73,
#    'timeLabel': '2022',
#    'timeMid': '2022.5',
#    'categoryId': 100,
#    'category': 'Married or in a union women',
#    'estimateTypeId': 1,
#    'estimateType': 'Model-based Estimates',
#    'estimateMethodId': 3,
#    'estimateMethod': 'Projection',
#    'sexId': 2,
#    'sex': 'Female',
#    'ageId': 31,
#    'ageLabel': '15-49',
#    'ageStart': 15,
#    'ageEnd': 49,
#    'ageMid': 32.5,
#    'value': 833233},
#   {'locationId': 710,
#    'location': 'South Africa',
#    'iso3': 'ZAF',
#    'iso2': 'ZA',
#    'locationTypeId': 4,
#    'indicatorId': 12,
#    'indicator': 'Unmet need for family planning: Any modern method (Number)',
#    'indicatorDisplayName': 'Unmet need modern',
#    'sourceId': 23,
#    'source': 'Estimates and Projections of Family Planning Indicators',
#    'revision': 0,
#    'variantId': 4,
#    'variant': 'Median',
#    'variantShortName': 'Median',
#    'variantLabel': 'Median',
#    'timeId': 73,
#    'timeLabel': '2022',
#    'timeMid': '2022.5',
#    'categoryId': 101,
#    'category': 'Unmarried women',
#    'estimateTypeId': 1,
#    'estimateType': 'Model-based Estimates',
#    'estimateMethodId': 3,
#    'estimateMethod': 'Projection',
#    'sexId': 2,
#    'sex': 'Female',
#    'ageId': 31,
#    'ageLabel': '15-49',
#    'ageStart': 15,
#    'ageEnd': 49,
#    'ageMid': 32.5,
#    'value': 942569},
#   {'locationId': 710,
#    'location': 'South Africa',
#    'iso3': 'ZAF',
#    'iso2': 'ZA',
#    'locationTypeId': 4,
#    'indicatorId': 12,
#    'indicator': 'Unmet need for family planning: Any modern method (Number)',
#    'indicatorDisplayName': 'Unmet need modern',
#    'sourceId': 23,
#    'source': 'Estimates and Projections of Family Planning Indicators',
#    'revision': 0,
#    'variantId': 5,
#    'variant': '80% upper bound',
#    'variantShortName': 'UPPER80',
#    'variantLabel': '80% Upper',
#    'timeId': 73,
#    'timeLabel': '2022',
#    'timeMid': '2022.5',
#    'categoryId': 99,
#    'category': 'All women',
#    'estimateTypeId': 1,
#    'estimateType': 'Model-based Estimates',
#    'estimateMethodId': 3,
#    'estimateMethod': 'Projection',
#    'sexId': 2,
#    'sex': 'Female',
#    'ageId': 31,
#    'ageLabel': '15-49',
#    'ageStart': 15,
#    'ageEnd': 49,
#    'ageMid': 32.5,
#    'value': 2387701},
#   {'locationId': 710,
#    'location': 'South Africa',
#    'iso3': 'ZAF',
#    'iso2': 'ZA',
#    'locationTypeId': 4,
#    'indicatorId': 12,
#    'indicator': 'Unmet need for family planning: Any modern method (Number)',
#    'indicatorDisplayName': 'Unmet need modern',
#    'sourceId': 23,
#    'source': 'Estimates and Projections of Family Planning Indicators',
#    'revision': 0,
#    'variantId': 5,
#    'variant': '80% upper bound',
#    'variantShortName': 'UPPER80',
#    'variantLabel': '80% Upper',
#    'timeId': 73,
#    'timeLabel': '2022',
#    'timeMid': '2022.5',
#    'categoryId': 100,
#    'category': 'Married or in a union women',
#    'estimateTypeId': 1,
#    'estimateType': 'Model-based Estimates',
#    'estimateMethodId': 3,
#    'estimateMethod': 'Projection',
#    'sexId': 2,
#    'sex': 'Female',
#    'ageId': 31,
#    'ageLabel': '15-49',
#    'ageStart': 15,
#    'ageEnd': 49,
#    'ageMid': 32.5,
#    'value': 1092338},
#   {'locationId': 710,
#    'location': 'South Africa',
#    'iso3': 'ZAF',
#    'iso2': 'ZA',
#    'locationTypeId': 4,
#    'indicatorId': 12,
#    'indicator': 'Unmet need for family planning: Any modern method (Number)',
#    'indicatorDisplayName': 'Unmet need modern',
#    'sourceId': 23,
#    'source': 'Estimates and Projections of Family Planning Indicators',
#    'revision': 0,
#    'variantId': 5,
#    'variant': '80% upper bound',
#    'variantShortName': 'UPPER80',
#    'variantLabel': '80% Upper',
#    'timeId': 73,
#    'timeLabel': '2022',
#    'timeMid': '2022.5',
#    'categoryId': 101,
#    'category': 'Unmarried women',
#    'estimateTypeId': 1,
#    'estimateType': 'Model-based Estimates',
#    'estimateMethodId': 3,
#    'estimateMethod': 'Projection',
#    'sexId': 2,
#    'sex': 'Female',
#    'ageId': 31,
#    'ageLabel': '15-49',
#    'ageStart': 15,
#    'ageEnd': 49,
#    'ageMid': 32.5,
#    'value': 1358908},
#   {'locationId': 710,
#    'location': 'South Africa',
#    'iso3': 'ZAF',
#    'iso2': 'ZA',
#    'locationTypeId': 4,
#    'indicatorId': 12,
#    'indicator': 'Unmet need for family planning: Any modern method (Number)',
#    'indicatorDisplayName': 'Unmet need modern',
#    'sourceId': 23,
#    'source': 'Estimates and Projections of Family Planning Indicators',
#    'revision': 0,
#    'variantId': 6,
#    'variant': '95% upper bound',
#    'variantShortName': 'UPPER95',
#    'variantLabel': '95% Upper',
#    'timeId': 73,
#    'timeLabel': '2022',
#    'timeMid': '2022.5',
#    'categoryId': 99,
#    'category': 'All women',
#    'estimateTypeId': 1,
#    'estimateType': 'Model-based Estimates',
#    'estimateMethodId': 3,
#    'estimateMethod': 'Projection',
#    'sexId': 2,
#    'sex': 'Female',
#    'ageId': 31,
#    'ageLabel': '15-49',
#    'ageStart': 15,
#    'ageEnd': 49,
#    'ageMid': 32.5,
#    'value': 2761375},
#   {'locationId': 710,
#    'location': 'South Africa',
#    'iso3': 'ZAF',
#    'iso2': 'ZA',
#    'locationTypeId': 4,
#    'indicatorId': 12,
#    'indicator': 'Unmet need for family planning: Any modern method (Number)',
#    'indicatorDisplayName': 'Unmet need modern',
#    'sourceId': 23,
#    'source': 'Estimates and Projections of Family Planning Indicators',
#    'revision': 0,
#    'variantId': 6,
#    'variant': '95% upper bound',
#    'variantShortName': 'UPPER95',
#    'variantLabel': '95% Upper',
#    'timeId': 73,
#    'timeLabel': '2022',
#    'timeMid': '2022.5',
#    'categoryId': 100,
#    'category': 'Married or in a union women',
#    'estimateTypeId': 1,
#    'estimateType': 'Model-based Estimates',
#    'estimateMethodId': 3,
#    'estimateMethod': 'Projection',
#    'sexId': 2,
#    'sex': 'Female',
#    'ageId': 31,
#    'ageLabel': '15-49',
#    'ageStart': 15,
#    'ageEnd': 49,
#    'ageMid': 32.5,
#    'value': 1251960},
#   {'locationId': 710,
#    'location': 'South Africa',
#    'iso3': 'ZAF',
#    'iso2': 'ZA',
#    'locationTypeId': 4,
#    'indicatorId': 12,
#    'indicator': 'Unmet need for family planning: Any modern method (Number)',
#    'indicatorDisplayName': 'Unmet need modern',
#    'sourceId': 23,
#    'source': 'Estimates and Projections of Family Planning Indicators',
#    'revision': 0,
#    'variantId': 6,
#    'variant': '95% upper bound',
#    'variantShortName': 'UPPER95',
#    'variantLabel': '95% Upper',
#    'timeId': 73,
#    'timeLabel': '2022',
#    'timeMid': '2022.5',
#    'categoryId': 101,
#    'category': 'Unmarried women',
#    'estimateTypeId': 1,
#    'estimateType': 'Model-based Estimates',
#    'estimateMethodId': 3,
#    'estimateMethod': 'Projection',
#    'sexId': 2,
#    'sex': 'Female',
#    'ageId': 31,
#    'ageLabel': '15-49',
#    'ageStart': 15,
#    'ageEnd': 49,
#    'ageMid': 32.5,
#    'value': 1643852}]}
